# %%
import pandas as pd

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
df = pd.read_csv('/content/drive/MyDrive/dataset/Netflix_dataset (3).csv')
df.head(20)
# Out:
#    show_id     type                                              title  \
# 0       s1    Movie                               Dick Johnson Is Dead
# 1       s2  TV Show                                      Blood & Water
# 2       s3  TV Show                                          Ganglands
# 3       s4  TV Show                              Jailbirds New Orleans
# 4       s5  TV Show                                       Kota Factory
# 5       s6  TV Show                                      Midnight Mass
# 6       s7    Movie                   My Little Pony: A New Generation
# 7       s8    Movie                                            Sankofa
# 8       s9  TV Show                      The Great British Baking Show
# 9      s10    Movie                                       The Starling
# 10     s11  TV Show                Vendetta: Truth, Lies and The Mafia
# 11     s12  TV Show                                   Bangkok Breaking
# ...

# %%
# What is the shape of the dataset (number of rows and columns)?

df.shape
# Out:
# (8807, 12)

# %%
# What are the first few entries in the dataset?

df.head(20)
# Out:
#    show_id     type                                              title  \
# 0       s1    Movie                               Dick Johnson Is Dead
# 1       s2  TV Show                                      Blood & Water
# 2       s3  TV Show                                          Ganglands
# 3       s4  TV Show                              Jailbirds New Orleans
# 4       s5  TV Show                                       Kota Factory
# 5       s6  TV Show                                      Midnight Mass
# 6       s7    Movie                   My Little Pony: A New Generation
# 7       s8    Movie                                            Sankofa
# 8       s9  TV Show                      The Great British Baking Show
# 9      s10    Movie                                       The Starling
# 10     s11  TV Show                Vendetta: Truth, Lies and The Mafia
# 11     s12  TV Show                                   Bangkok Breaking
# ...

# %%
# How many unique values are there in each column?

df.nunique()
# Out:
# show_id         8807
# type               2
# title           8807
# director        4528
# cast            7692
# country          748
# date_added      1767
# release_year      74
# rating            17
# duration         220
# listed_in        514
# description     8775
# dtype: int64

# %%
# 4. What are the data types of each colum

df.dtypes
# Out:
# show_id         object
# type            object
# title           object
# director        object
# cast            object
# country         object
# date_added      object
# release_year     int64
# rating          object
# duration        object
# listed_in       object
# description     object
# dtype: object

# %%
# 5. How many missing values exist in each column?

df.isnull().sum()
# Out:
# show_id            0
# type               0
# title              0
# director        2634
# cast             825
# country          831
# date_added        10
# release_year       0
# rating             4
# duration           3
# listed_in          0
# description        0
# dtype: int64

# %%
# How can missing values be handled in different columns?


df.describe()
# Out:
#        release_year
# count   8807.000000
# mean    2014.180198
# std        8.819312
# min     1925.000000
# 25%     2013.000000
# 50%     2017.000000
# 75%     2019.000000
# max     2021.000000

# %%
df.describe(include="object")
# Out:
#        show_id   type   title       director                cast  \
# count     8807   8807    8807           6173                7982
# unique    8807      2    8807           4528                7692
# top      s8807  Movie  Zubaan  Rajiv Chilaka  David Attenborough
# freq         1   6131       1             19                  19
#
#               country       date_added rating  duration  \
# count            7976             8797   8803      8804
# unique            748             1767     17       220
# top     United States  January 1, 2020  TV-MA  1 Season
# freq             2818              109   3207      1793
#
#                            listed_in  \
# count                           8807
# unique                           514
# top     Dramas, International Movies
# freq                             362
#
#                                               description
# count                                                8807
# ...

# %%
# since rating column is a categorical column we can remove missing values through mode imputation

df['rating']= df['rating'].fillna(df['rating'].mode()[0])

# %%
df.isnull().sum()
# Out:
# show_id            0
# type               0
# title              0
# director        2634
# cast             825
# country          831
# date_added        10
# release_year       0
# rating             0
# duration           3
# listed_in          0
# description        0
# dtype: int64

# %%
df['rating'].isnull().sum()
# Out:
# np.int64(0)

# %%
(df.isnull().mean() )*100
# Out:
# show_id          0.000000
# type             0.000000
# title            0.000000
# director        29.908028
# cast             9.367549
# country          9.435676
# date_added       0.113546
# release_year     0.000000
# rating           0.000000
# duration         0.034064
# listed_in        0.000000
# description      0.000000
# dtype: float64

# %%
df['duration'].value_counts()
# Out:
# duration
# 1 Season     1793
# 2 Seasons     425
# 3 Seasons     199
# 90 min        152
# 97 min        146
#              ...
# 228 min         1
# 18 min          1
# 205 min         1
# 201 min         1
# 191 min         1
# Name: count, Length: 220, dtype: int64

# %%
# since duration column is a categorical column we can remove missing values through mode imputation

df['duration']= df['duration'].fillna(df['rating'].mode()[0])

# %%
df.isnull().sum()
# Out:
# show_id            0
# type               0
# title              0
# director        2634
# cast             825
# country          831
# date_added        10
# release_year       0
# rating             0
# duration           0
# listed_in          0
# description        0
# dtype: int64

# %%
df['date_added'].value_counts()
# Out:
# date_added
# January 1, 2020       109
# November 1, 2019       89
# March 1, 2018          75
# December 31, 2019      74
# October 1, 2018        71
#                      ...
# February 2, 2017        1
# September 11, 2019      1
# May 17, 2015            1
# June 5, 2018            1
# October 14, 2017        1
# Name: count, Length: 1767, dtype: int64

# %%
df['date_added'].head(40)
# Out:
# 0     September 25, 2021
# 1     September 24, 2021
# 2     September 24, 2021
# 3     September 24, 2021
# 4     September 24, 2021
# 5     September 24, 2021
# 6     September 24, 2021
# 7     September 24, 2021
# 8     September 24, 2021
# 9     September 24, 2021
# 10    September 24, 2021
# 11    September 23, 2021
# 12    September 23, 2021
# 13    September 22, 2021
# 14    September 22, 2021
# 15    September 22, 2021
# 16    September 22, 2021
# 17    September 22, 2021
# 18    September 22, 2021
# 19    September 22, 2021
# 20    September 22, 2021
# 21    September 22, 2021
# 22    September 21, 2021
# 23    September 21, 2021
# 24    September 21, 2021
# 25    September 21, 2021
# 26    September 21, 2021
# 27    September 20, 2021
# 28    September 19, 2021
# 29    September 19, 2021
# 30    September 17, 2021
# 31    September 17, 2021
# 32    September 17, 2021
# 33    September 17, 2021
# 34    September 17, 2021
# 35    September 17, 2021
# 36    September 17, 2021
# ...

# %%
# to handle the null values of date_added colum we are applying the forward fill

df['date_added'].ffill(inplace=True)

# %%
# to handle null values of director column

df['director'].value_counts()
# Out:
# director
# Unknown                                   2634
# Rajiv Chilaka                               19
# Raúl Campos, Jan Suter                      18
# Suhas Kadav                                 16
# Marcus Raboy                                16
#                                           ...
# Milla Harrison-Hansley, Alicky Sussman       1
# Drew Stone                                   1
# Benjamin Turner                              1
# S. Shankar                                   1
# Peter Hewitt                                 1
# Name: count, Length: 4529, dtype: int64

# %%
# we are replacing the null values of director column with unknown

df['director'].fillna(value='Unknown', inplace = True)

# %%
# to handle null values of cast column

df['cast'].value_counts()
# Out:
# cast
# David Attenborough                                                                                                                                                      19
# Vatsal Dubey, Julie Tejwani, Rupa Bhimani, Jigna Bhardwaj, Rajesh Kava, Mousam, Swapnil                                                                                 14
# Samuel West                                                                                                                                                             10
# Jeff Dunham                                                                                                                                                              7
# Michela Luci, Jamie Watson, Eric Peterson, Anna Claire Bartlam, Nicolas Aqui, Cory Doran, Julie Lemieux, Derek McGrath                                                   6
# ...

# %%
# we are replacing the cast column null values with unknown

df['cast'].fillna(value='Unknown', inplace = True)

# %%
# to handle null values of country column

df['country'].value_counts()
# Out:
# country
# United States                                                      2818
# India                                                               972
# United Kingdom                                                      419
# Japan                                                               245
# South Korea                                                         199
#                                                                    ...
# Mexico, United States, Spain, Colombia                                1
# Canada, Norway                                                        1
# Finland, Germany, Belgium                                             1
# Argentina, United States, Mexico                                      1
# United Kingdom, United States, Germany, Denmark, Belgium, Japan       1
# Name: count, Length: 748, dtype: int64

# %%
# we are replacing the country column null values with  unknown

df['country'].fillna(value='Unknown', inplace = True)

# %%
df.isnull().sum()
# Out:
# show_id         0
# type            0
# title           0
# director        0
# cast            0
# country         0
# date_added      0
# release_year    0
# rating          0
# duration        0
# listed_in       0
# description     0
# dtype: int64

# %%
# 7. Are there any incorrect or inconsistent values in the dataset?

df_ = df.select_dtypes(exclude=['int', 'float'])
for col in df_.columns:
    print(df_.loc[0:1, col])

    print(df_[col].value_counts())
    print("___________________________________________")
# Out:
# 0    s1
# 1    s2
# Name: show_id, dtype: object
# show_id
# s8807    1
# s1       1
# s2       1
# s3       1
# s4       1
#         ..
# s12      1
# s11      1
# s10      1
# s9       1
# s8       1
# Name: count, Length: 8807, dtype: int64
# ___________________________________________
# 0      Movie
# 1    TV Show
# Name: type, dtype: object
# type
# Movie      6131
# TV Show    2676
# Name: count, dtype: int64
# ___________________________________________
# 0    Dick Johnson Is Dead
# 1           Blood & Water
# Name: title, dtype: object
# title
# Zubaan                                 1
# Dick Johnson Is Dead                   1
# Blood & Water                          1
# Ganglands                              1
# Jailbirds New Orleans                  1
#                                       ..
# Bangkok Breaking                       1
# Vendetta: Truth, Lies and The Mafia    1
# The Starling                           1
# The Great British Baking Show          1
# ...

# %%
""" Comment: after watching the data
 carefully their are no incorrect and
 inconsistent value in the data set """
# Out:
# ' Comment: after watching the data\n carefully their are no incorrect and\n inconsistent value in the data set '

# %%
# 8. What transformations are needed to convert data into the correct format?

""" The transformation needed to convert data into the correct
 format are remove duplicate handle missing values , check correct data types e.tc

    """

df.duplicated().sum()

# hence there are no duplicates.
# Out:
# np.int64(0)

# %%
# 9. How can we convert the date_added column into a proper datetime format?



df['date_added'] = pd.to_datetime(df['date_added'], errors='coerce')
print(df['date_added'].head(20))
# Out:
# 0    2021-09-25
# 1    2021-09-24
# 2    2021-09-24
# 3    2021-09-24
# 4    2021-09-24
# 5    2021-09-24
# 6    2021-09-24
# 7    2021-09-24
# 8    2021-09-24
# 9    2021-09-24
# 10   2021-09-24
# 11   2021-09-23
# 12   2021-09-23
# 13   2021-09-22
# 14   2021-09-22
# 15   2021-09-22
# 16   2021-09-22
# 17   2021-09-22
# 18   2021-09-22
# 19   2021-09-22
# Name: date_added, dtype: datetime64[ns]

# %%
# 10. What are the unique content types (Movie/TV Show) in the dataset?

df['type'].unique()
# Out:
# array(['Movie', 'TV Show'], dtype=object)

# %%
# 11. What is the distribution of content (Movies vs. TV Shows) on Netflix?

import seaborn as sns
import matplotlib.pyplot as plt
sns.countplot(data = df, x = 'type')
plt.title('distribution of content (Movies vs. TV Shows)')
plt.show()

# %%
# 12. What are the different ratings available on Netflix, and how are they distributed?


sns.countplot(data = df, x = 'rating')
plt.title('distribution of ratings')
plt.xticks(rotation=90)
plt.show()

# %%
# 13. How many unique genres are available in the dataset?

"""

df_ = df.select_dtypes(exclude=['int', 'float'])
for col in df_.columns:
    print(df_.loc[0:1, col])
    unique_genres = set(genre.strip() for genres in df[col] for genre in genres.split(','))
    print("Unique Genres:", unique_genres)
    print("___________________________________________")

"""
# since we have genres available in only  3 column  (country,cast and listed_in so unique generes  are )
unique_genres1 = set(genre.strip() for genres in df['country'] for genre in genres.split(','))
unique_genres2 = set(genre.strip() for genres in df['cast'] for genre in genres.split(','))
unique_genres3 = set(genre.strip() for genres in df['listed_in'] for genre in genres.split(','))

print(unique_genres1)
print(unique_genres2)
print(unique_genres3)

# not complete
# Out:
# {'', 'Brazil', 'Unknown', 'Mongolia', 'Chile', 'Spain', 'Ukraine', 'Latvia', 'Czech Republic', 'Croatia', 'Venezuela', 'Slovakia', 'China', 'Philippines', 'Uruguay', 'Belgium', 'Mauritius', 'Iran', 'Romania', 'Montenegro', 'Serbia', 'Vatican City', 'Slovenia', 'Colombia', 'Bulgaria', 'Finland', 'Cameroon', 'Austria', 'Botswana', 'Lithuania', 'Egypt', 'Cayman Islands', 'Dominican Republic', 'Kazakhstan', 'Argentina', 'Pakistan', 'Albania', 'Israel', 'Zimbabwe', 'Panama', 'Mexico', 'Thailand', 'Guatemala', 'United Kingdom', 'Portugal', 'Russia', 'Ireland', 'Angola', 'Greece', 'Senegal', 'Ecuador', 'Iraq', 'Nicaragua', 'Ethiopia', 'Peru', 'Australia', 'France', 'Sweden', 'Nigeria', 'Afghanistan', 'Hong Kong', 'Netherlands', 'Puerto Rico', 'Azerbaijan', 'Cambodia', 'Bermuda', 'Sudan', 'Malta', 'Burkina Faso', 'Hungary', 'Algeria', 'Canada', 'Switzerland', 'United States', 'New Zealand', 'Samoa', 'Jordan', 'Japan', 'Germany', 'West Germany', 'Indonesia', 'Georgia', 'Saudi Arabia', 'Lebano
# ...

# %%
# 14. How many movies and TV shows have been directed by each director?

director_counts = df.groupby(['director', 'type']).size().unstack(fill_value=0)
print(director_counts.tail(50))
# Out:
# type                                                Movie  TV Show
# director
# Young Jun Lee                                           1        0
# Younuts!                                                1        0
# Youssef Chahine                                        12        0
# Yu Yang                                                 1        0
# Yudai Yamaguchi                                         1        0
# Yuen Wo-Ping                                            1        0
# Yuen Woo-ping                                           1        0
# Yuki Tanada                                             1        0
# Yuki Yamato                                             1        0
# Yulene Olaizola                                         1        0
# Yusuf Pirhasan                                          1        0
# Yuval Adler                                             1        0
# Yvan Attal                                              1        0
# ...

# %%
# 15. How many shows/movies were added to Netflix each year?


df['year_added'] = df['date_added'].dt.year
Movies_each_year = df.groupby(['year_added', 'type']).size().unstack(fill_value=0)
print(Movies_each_year.head(50))

# Print the result
# Out:
# type        Movie  TV Show
# year_added
# 2008.0          1        1
# 2009.0          2        0
# 2010.0          1        0
# 2011.0         13        0
# 2012.0          3        0
# 2013.0          6        4
# 2014.0         19        4
# 2015.0         56       17
# 2016.0        253      166
# 2017.0        839      330
# 2018.0       1237      391
# 2019.0       1424      576
# 2020.0       1284      594
# 2021.0        993      505
